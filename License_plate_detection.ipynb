# %%
! pip install -q ultralytics

# %%
from ultralytics import YOLO
from sklearn import metrics
import matplotlib.pyplot as plt
import cv2

# %%
model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 65.0MB/s]

# %%
model.train(data='/content/persian_license_plate.yaml',epochs=40, imgsz=512)
# Out:
# Ultralytics YOLOv8.0.212 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
val_evaluate = model.val()
# Out:
# Ultralytics YOLOv8.0.212 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/License_Plate/labels/valid.cache... 181 images, 5 backgrounds, 0 corrupt: 100%|██████████| 181/181 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 25, len(boxes) = 415. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 12/12 [00:05<00:00,  2.30it/s]
#                    all        181        415      0.862      0.693      0.734        0.4
# Speed: 0.4ms preprocess, 5.2ms inference, 0.0ms loss, 3.3ms postprocess per image
# Results saved to runs/detect/train22

# %%
val_evaluate

# %%
cm = val_evaluate.confusion_matrix.matrix
cm
# Out:
# array([[        297,          42],
#        [        118,           0]])

# %%
plt.figure(figsize = (10,7))
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = ['True', 'False'])
cm_display.plot(cmap=plt.cm.Blues)

# %%
def bounding_box(file_path,img):
  dh, dw, _ = img.shape
  i = 0

  file = open(file_path,'r')
  for line in file:

    class_id, x_center, y_center, w, h = line.strip().split()
    x_center, y_center, w, h = float(x_center), float(y_center), float(w), float(h)
    x_center = round(x_center * dw)
    y_center = round(y_center * dh)
    w = round(w * dw)
    h = round(h * dh)
    x = round(x_center - w / 2)
    y = round(y_center - h / 2)

    imgCrop = img1[y:y + h, x:x + w]
    cv2.imwrite('/content/runs/detect/predict/image_crop'+str(i)+'.jpg',imgCrop)
    i += 1

# %%
new_model = YOLO('/content/runs/detect/train2/weights/best.pt')

# %%
results = new_model("/content/drive/MyDrive/License_Plate/images/test/photo_2023-11-07_14-35-25_jpg.rf.4ccf9602ee9992ab22d3501245ab1d06.jpg"
,save=True, save_txt=True, imgsz=512)  # predict on an image
# Out:
# image 1/1 /content/drive/MyDrive/License_Plate/images/test/photo_2023-11-07_14-35-25_jpg.rf.4ccf9602ee9992ab22d3501245ab1d06.jpg: 512x512 2 License-Plates, 13.9ms
# Speed: 3.2ms preprocess, 13.9ms inference, 2.9ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to runs/detect/predict
# 2 labels saved to runs/detect/predict/labels

# %%
img1 = cv2.imread('/content/runs/detect/predict/photo_2023-11-07_14-35-25_jpg.rf.4ccf9602ee9992ab22d3501245ab1d06.jpg')
img1 = cv2.cvtColor(img1 , cv2.COLOR_BGR2RGB)
plt.imshow(img1)

# %%
bounding_box('/content/runs/detect/predict/labels/photo_2023-11-14_17-07-59_jpg.rf.ce0aff2c1df8bc95511171dce23a0562.txt',img1)

# %%
results = new_model("/content/drive/MyDrive/License_Plate/images/test/photo_2023-11-08_18-15-49_jpg.rf.f76788cb9fb01fbc1574fb4c49d6fd84.jpg",
                    save=True,save_crop=True)  # predict on an image
# Out:
# image 1/1 /content/drive/MyDrive/License_Plate/images/test/photo_2023-11-08_18-15-49_jpg.rf.f76788cb9fb01fbc1574fb4c49d6fd84.jpg: 640x640 4 License-Plates, 16.5ms
# Speed: 1.8ms preprocess, 16.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
results = new_model("/content/drive/MyDrive/License_Plate/images/test/photo_2023-11-14_17-07-59_jpg.rf.ce0aff2c1df8bc95511171dce23a0562.jpg"
,save=True, save_txt=True, imgsz=512)  # predict on an image
# Out:
# image 1/1 /content/drive/MyDrive/License_Plate/images/test/photo_2023-11-14_17-07-59_jpg.rf.ce0aff2c1df8bc95511171dce23a0562.jpg: 512x512 3 License-Plates, 13.1ms
# Speed: 2.9ms preprocess, 13.1ms inference, 2.7ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to runs/detect/predict
# 3 labels saved to runs/detect/predict/labels

# %%
img1 = cv2.imread('/content/runs/detect/predict/photo_2023-11-14_17-07-59_jpg.rf.ce0aff2c1df8bc95511171dce23a0562.jpg')
img1 = cv2.cvtColor(img1 , cv2.COLOR_BGR2RGB)
plt.imshow(img1)

# %%
bounding_box('/content/runs/detect/predict/labels/photo_2023-11-14_17-07-59_jpg.rf.ce0aff2c1df8bc95511171dce23a0562.txt',img1)
